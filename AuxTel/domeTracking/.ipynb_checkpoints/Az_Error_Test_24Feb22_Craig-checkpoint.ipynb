# %% [markdown]
# ## Motion Tests - 8s azimuth oscillation investigation
#
#
# Author: Craig Lage <br>
# Copied from: https://github.com/craiglagegit/ScratchStuff/blob/master/notebooks/Az_Error_Test_24Feb22.ipynb

# %%
import sys, time, os, asyncio

from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
import pandas as pd
from astropy.time import Time, TimeDelta
from lsst_efd_client import EfdClient

# %%
# for tab completion to work in current notebook instance
# %config IPCompleter.use_jedi = False

# %%
import logging
stream_handler = logging.StreamHandler(sys.stdout)
logger = logging.getLogger()
logger.addHandler(stream_handler)
logger.level = logging.DEBUG

# %%
# Get EFD client and bring in Lupton's unpacking code
client = EfdClient('summit_efd')
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">urllib3.connectionpool</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Starting new HTTPS connection (1): roundtable.lsst.codes:443</pre>
# Starting new HTTPS connection (1): roundtable.lsst.codes:443
# Starting new HTTPS connection (1): roundtable.lsst.codes:443
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">urllib3.connectionpool</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: https://roundtable.lsst.codes:443 &quot;GET /segwarides/ HTTP/1.1&quot; 200 253</pre>
# https://roundtable.lsst.codes:443 "GET /segwarides/ HTTP/1.1" 200 253
# https://roundtable.lsst.codes:443 "GET /segwarides/ HTTP/1.1" 200 253
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">urllib3.connectionpool</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Starting new HTTPS connection (1): roundtable.lsst.codes:443</pre>
# Starting new HTTPS connection (1): roundtable.lsst.codes:443
# Starting new HTTPS connection (1): roundtable.lsst.codes:443
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">urllib3.connectionpool</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: https://roundtable.lsst.codes:443 &quot;GET /segwarides/creds/summit_efd HTTP/1.1&quot; 200 177</pre>
# https://roundtable.lsst.codes:443 "GET /segwarides/creds/summit_efd HTTP/1.1" 200 177
# https://roundtable.lsst.codes:443 "GET /segwarides/creds/summit_efd HTTP/1.1" 200 177
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">urllib3.connectionpool</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Starting new HTTPS connection (1): influxdb-summit-efd.lsst.codes:30828</pre>
# Starting new HTTPS connection (1): influxdb-summit-efd.lsst.codes:30828
# Starting new HTTPS connection (1): influxdb-summit-efd.lsst.codes:30828
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">urllib3.connectionpool</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: https://influxdb-summit-efd.lsst.codes:30828 &quot;GET /health HTTP/1.1&quot; 200 106</pre>
# https://influxdb-summit-efd.lsst.codes:30828 "GET /health HTTP/1.1" 200 106
# https://influxdb-summit-efd.lsst.codes:30828 "GET /health HTTP/1.1" 200 106

# %% [markdown]
# # EL 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:27:00", scale='utc')
tend = Time("2022-03-01T19:29:00", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:27:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:29:00.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:27:00.000Z' AND time <= '2022-03-01T19:29:00.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:27:00.000Z' AND time <= '2022-03-01T19:29:00.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:27:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:29:00.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:27:00.000Z' AND time <= '2022-03-01T19:29:00.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:27:00.000Z' AND time <= '2022-03-01T19:29:00.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220301\nStarting Az=0, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el80.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # El 70

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:31:30", scale='utc')
tend = Time("2022-03-01T19:33:30", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:31:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:33:30.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:31:30.000Z' AND time <= '2022-03-01T19:33:30.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:31:30.000Z' AND time <= '2022-03-01T19:33:30.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:31:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:33:30.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:31:30.000Z' AND time <= '2022-03-01T19:33:30.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:31:30.000Z' AND time <= '2022-03-01T19:33:30.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220301\nStarting Az=0, Starting El=70", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el70.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # EL 60

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:36:30", scale='utc')
tend = Time("2022-03-01T19:38:30", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:36:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:38:30.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:36:30.000Z' AND time <= '2022-03-01T19:38:30.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:36:30.000Z' AND time <= '2022-03-01T19:38:30.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:36:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:38:30.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:36:30.000Z' AND time <= '2022-03-01T19:38:30.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:36:30.000Z' AND time <= '2022-03-01T19:38:30.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220103\nStarting Az=0, Starting El=60", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el60.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # EL 50

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:43:00", scale='utc')
tend = Time("2022-03-01T19:45:00", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:43:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:45:00.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:43:00.000Z' AND time <= '2022-03-01T19:45:00.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:43:00.000Z' AND time <= '2022-03-01T19:45:00.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:43:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:45:00.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:43:00.000Z' AND time <= '2022-03-01T19:45:00.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:43:00.000Z' AND time <= '2022-03-01T19:45:00.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220103\nStarting Az=0, Starting El=50", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el50.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # El 40

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:48:00", scale='utc')
tend = Time("2022-03-01T19:50:00", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:48:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:50:00.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:48:00.000Z' AND time <= '2022-03-01T19:50:00.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:48:00.000Z' AND time <= '2022-03-01T19:50:00.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:48:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:50:00.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:48:00.000Z' AND time <= '2022-03-01T19:50:00.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:48:00.000Z' AND time <= '2022-03-01T19:50:00.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220103\nStarting Az=0, Starting El=40", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el40.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # El 25

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:53:00", scale='utc')
tend = Time("2022-03-01T19:55:00", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:53:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:55:00.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:53:00.000Z' AND time <= '2022-03-01T19:55:00.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:53:00.000Z' AND time <= '2022-03-01T19:55:00.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:53:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T19:55:00.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:53:00.000Z' AND time <= '2022-03-01T19:55:00.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:53:00.000Z' AND time <= '2022-03-01T19:55:00.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220301\nStarting Az=0, Starting El=25", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el25.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # EL 80 Back to 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T19:59:30", scale='utc')
tend = Time("2022-03-01T20:01:30", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:59:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:01:30.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:59:30.000Z' AND time <= '2022-03-01T20:01:30.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:59:30.000Z' AND time <= '2022-03-01T20:01:30.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T19:59:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:01:30.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:59:30.000Z' AND time <= '2022-03-01T20:01:30.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T19:59:30.000Z' AND time <= '2022-03-01T20:01:30.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220301\Back to Az=0, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az0el80_Backto.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Modifying azimuths Az = 10, EL = 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T20:04:00", scale='utc')
tend = Time("2022-03-01T20:06:00", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:04:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:06:00.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:04:00.000Z' AND time <= '2022-03-01T20:06:00.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:04:00.000Z' AND time <= '2022-03-01T20:06:00.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:04:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:06:00.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:04:00.000Z' AND time <= '2022-03-01T20:06:00.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:04:00.000Z' AND time <= '2022-03-01T20:06:00.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220301\nStarting Az=10, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az10el80.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Az = 20 , EL = 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T20:09:00", scale='utc')
tend = Time("2022-03-01T20:11:00", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:09:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:11:00.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:09:00.000Z' AND time <= '2022-03-01T20:11:00.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:09:00.000Z' AND time <= '2022-03-01T20:11:00.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:09:00.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:11:00.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:09:00.000Z' AND time <= '2022-03-01T20:11:00.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:09:00.000Z' AND time <= '2022-03-01T20:11:00.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220224\nStarting Az=20, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az20el80.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Az = 30 , EL = 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T20:14:30", scale='utc')
tend = Time("2022-03-01T20:16:30", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:14:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:16:30.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:14:30.000Z' AND time <= '2022-03-01T20:16:30.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:14:30.000Z' AND time <= '2022-03-01T20:16:30.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:14:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:16:30.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:14:30.000Z' AND time <= '2022-03-01T20:16:30.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:14:30.000Z' AND time <= '2022-03-01T20:16:30.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220103\nStarting Az=30, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az30el80.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Az = 45 , EL = 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T20:19:30", scale='utc')
tend = Time("2022-03-01T20:21:30", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:19:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:21:30.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:19:30.000Z' AND time <= '2022-03-01T20:21:30.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:19:30.000Z' AND time <= '2022-03-01T20:21:30.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:19:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:21:30.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:19:30.000Z' AND time <= '2022-03-01T20:21:30.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:19:30.000Z' AND time <= '2022-03-01T20:21:30.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220103\nStarting Az=45, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az45el80.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Az = 60 , EL = 80

# %%
# Blow up the first two minutes to look at the periodic error
tstart = Time("2022-03-01T20:24:30", scale='utc')
tend = Time("2022-03-01T20:25:10", scale='utc')
az = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "azimuthCalculatedAngle",  tstart, tend)
el = await client.select_packed_time_series("lsst.sal.ATMCS.mount_AzEl_Encoders", "elevationCalculatedAngle",  tstart, tend)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:24:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:25:10.000Z&#x27;</pre>
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:24:30.000Z' AND time <= '2022-03-01T20:25:10.000Z'
# 200: SELECT azimuthCalculatedAngle0, azimuthCalculatedAngle1, azimuthCalculatedAngle2, azimuthCalculatedAngle3, azimuthCalculatedAngle4, azimuthCalculatedAngle5, azimuthCalculatedAngle6, azimuthCalculatedAngle7, azimuthCalculatedAngle8, azimuthCalculatedAngle9, azimuthCalculatedAngle10, azimuthCalculatedAngle11, azimuthCalculatedAngle12, azimuthCalculatedAngle13, azimuthCalculatedAngle14, azimuthCalculatedAngle15, azimuthCalculatedAngle16, azimuthCalculatedAngle17, azimuthCalculatedAngle18, azimuthCalculatedAngle19, azimuthCalculatedAngle20, azimuthCalculatedAngle21, azimuthCalculatedAngle22, azimuthCalculatedAngle23, azimuthCalculatedAngle24, azimuthCalculatedAngle25, azimuthCalculatedAngle26, azimuthCalculatedAngle27, azimuthCalculatedAngle28, azimuthCalculatedAngle29, azimuthCalculatedAngle30, azimuthCalculatedAngle31, azimuthCalculatedAngle32, azimuthCalculatedAngle33, azimuthCalculatedAngle34, azimuthCalculatedAngle35, azimuthCalculatedAngle36, azimuthCalculatedAngle37, azimuthCalculatedAngle38, azimuthCalculatedAngle39, azimuthCalculatedAngle40, azimuthCalculatedAngle41, azimuthCalculatedAngle42, azimuthCalculatedAngle43, azimuthCalculatedAngle44, azimuthCalculatedAngle45, azimuthCalculatedAngle46, azimuthCalculatedAngle47, azimuthCalculatedAngle48, azimuthCalculatedAngle49, azimuthCalculatedAngle50, azimuthCalculatedAngle51, azimuthCalculatedAngle52, azimuthCalculatedAngle53, azimuthCalculatedAngle54, azimuthCalculatedAngle55, azimuthCalculatedAngle56, azimuthCalculatedAngle57, azimuthCalculatedAngle58, azimuthCalculatedAngle59, azimuthCalculatedAngle60, azimuthCalculatedAngle61, azimuthCalculatedAngle62, azimuthCalculatedAngle63, azimuthCalculatedAngle64, azimuthCalculatedAngle65, azimuthCalculatedAngle66, azimuthCalculatedAngle67, azimuthCalculatedAngle68, azimuthCalculatedAngle69, azimuthCalculatedAngle70, azimuthCalculatedAngle71, azimuthCalculatedAngle72, azimuthCalculatedAngle73, azimuthCalculatedAngle74, azimuthCalculatedAngle75, azimuthCalculatedAngle76, azimuthCalculatedAngle77, azimuthCalculatedAngle78, azimuthCalculatedAngle79, azimuthCalculatedAngle80, azimuthCalculatedAngle81, azimuthCalculatedAngle82, azimuthCalculatedAngle83, azimuthCalculatedAngle84, azimuthCalculatedAngle85, azimuthCalculatedAngle86, azimuthCalculatedAngle87, azimuthCalculatedAngle88, azimuthCalculatedAngle89, azimuthCalculatedAngle90, azimuthCalculatedAngle91, azimuthCalculatedAngle92, azimuthCalculatedAngle93, azimuthCalculatedAngle94, azimuthCalculatedAngle95, azimuthCalculatedAngle96, azimuthCalculatedAngle97, azimuthCalculatedAngle98, azimuthCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:24:30.000Z' AND time <= '2022-03-01T20:25:10.000Z'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SHOW FIELD KEYS FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot;</pre>
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# 200: SHOW FIELD KEYS FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders"
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">aioinflux</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM &quot;efd&quot;.&quot;autogen&quot;.&quot;lsst.sal.ATMCS.mount_AzEl_Encoders&quot; WHERE time &gt;= &#x27;2022-03-01T20:24:30.000Z&#x27; AND time &lt;= &#x27;2022-03-01T20:25:10.000Z&#x27;</pre>
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:24:30.000Z' AND time <= '2022-03-01T20:25:10.000Z'
# 200: SELECT elevationCalculatedAngle0, elevationCalculatedAngle1, elevationCalculatedAngle2, elevationCalculatedAngle3, elevationCalculatedAngle4, elevationCalculatedAngle5, elevationCalculatedAngle6, elevationCalculatedAngle7, elevationCalculatedAngle8, elevationCalculatedAngle9, elevationCalculatedAngle10, elevationCalculatedAngle11, elevationCalculatedAngle12, elevationCalculatedAngle13, elevationCalculatedAngle14, elevationCalculatedAngle15, elevationCalculatedAngle16, elevationCalculatedAngle17, elevationCalculatedAngle18, elevationCalculatedAngle19, elevationCalculatedAngle20, elevationCalculatedAngle21, elevationCalculatedAngle22, elevationCalculatedAngle23, elevationCalculatedAngle24, elevationCalculatedAngle25, elevationCalculatedAngle26, elevationCalculatedAngle27, elevationCalculatedAngle28, elevationCalculatedAngle29, elevationCalculatedAngle30, elevationCalculatedAngle31, elevationCalculatedAngle32, elevationCalculatedAngle33, elevationCalculatedAngle34, elevationCalculatedAngle35, elevationCalculatedAngle36, elevationCalculatedAngle37, elevationCalculatedAngle38, elevationCalculatedAngle39, elevationCalculatedAngle40, elevationCalculatedAngle41, elevationCalculatedAngle42, elevationCalculatedAngle43, elevationCalculatedAngle44, elevationCalculatedAngle45, elevationCalculatedAngle46, elevationCalculatedAngle47, elevationCalculatedAngle48, elevationCalculatedAngle49, elevationCalculatedAngle50, elevationCalculatedAngle51, elevationCalculatedAngle52, elevationCalculatedAngle53, elevationCalculatedAngle54, elevationCalculatedAngle55, elevationCalculatedAngle56, elevationCalculatedAngle57, elevationCalculatedAngle58, elevationCalculatedAngle59, elevationCalculatedAngle60, elevationCalculatedAngle61, elevationCalculatedAngle62, elevationCalculatedAngle63, elevationCalculatedAngle64, elevationCalculatedAngle65, elevationCalculatedAngle66, elevationCalculatedAngle67, elevationCalculatedAngle68, elevationCalculatedAngle69, elevationCalculatedAngle70, elevationCalculatedAngle71, elevationCalculatedAngle72, elevationCalculatedAngle73, elevationCalculatedAngle74, elevationCalculatedAngle75, elevationCalculatedAngle76, elevationCalculatedAngle77, elevationCalculatedAngle78, elevationCalculatedAngle79, elevationCalculatedAngle80, elevationCalculatedAngle81, elevationCalculatedAngle82, elevationCalculatedAngle83, elevationCalculatedAngle84, elevationCalculatedAngle85, elevationCalculatedAngle86, elevationCalculatedAngle87, elevationCalculatedAngle88, elevationCalculatedAngle89, elevationCalculatedAngle90, elevationCalculatedAngle91, elevationCalculatedAngle92, elevationCalculatedAngle93, elevationCalculatedAngle94, elevationCalculatedAngle95, elevationCalculatedAngle96, elevationCalculatedAngle97, elevationCalculatedAngle98, elevationCalculatedAngle99, cRIO_timestamp FROM "efd"."autogen"."lsst.sal.ATMCS.mount_AzEl_Encoders" WHERE time >= '2022-03-01T20:24:30.000Z' AND time <= '2022-03-01T20:25:10.000Z'

# %%
# Calculate the tracking errors
az_vals = np.array(az.values.tolist())[:,0]
el_vals = np.array(el.values.tolist())[:,0]
times = np.array(az.values.tolist())[:,1]
times = times - times [0]

# Fit with a quartic
az_fit = np.polyfit(times, az_vals, 4)
el_fit = np.polyfit(times, el_vals, 4)

az_model = az_fit[0] * times * times * times * times + az_fit[1] * times * times * times \
    + az_fit[2] * times *times + az_fit[3] * times + az_fit[4]
el_model = el_fit[0] * times * times * times * times + el_fit[1] * times * times * times \
    + el_fit[2] * times * times + el_fit[3] * times + el_fit[4]

# Errors in arcseconds
az_error = (az_vals - az_model) * 3600
el_error = (el_vals - el_model) * 3600

# Calculate RMS
az_rms = np.sqrt(np.mean(az_error * az_error))
el_rms = np.sqrt(np.mean(el_error * el_error))

# %%
# Plot it
fig = plt.figure(figsize = (8,8))
plt.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle(f"Mount Tracking Az Error 20220103\nStarting Az=60, Starting El=80", fontsize = 18)
plt.subplot(2,2,1)
ax1 = az['azimuthCalculatedAngle'].plot(legend=True, color='red')
ax1.set_ylabel("Degrees")
plt.subplot(2,2,2)
ax3 = el['elevationCalculatedAngle'].plot(legend=True, color='green')
ax3.set_ylabel("Degrees")

plt.subplot(2,2,3)
plt.plot(times, az_error, color='red')
plt.title(f"Azimuth RMS error = {az_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.subplot(2,2,4)
plt.plot(times, el_error, color='green')
plt.title(f"Elevation RMS error = {el_rms:.2f} arcseconds")
plt.ylim(-10.0,10.0)
plt.xticks([])
plt.ylabel("ArcSeconds")
plt.savefig(f"./Az_Error_Debug_1_1Mar22_az60el80.pdf")
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Assigning font /b&#x27;F1&#x27; = &#x27;/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf&#x27;</pre>
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# Assigning font /b'F1' = '/opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.</pre>
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# Embedding font /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-1.0.0/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">matplotlib.backends.backend_pdf</span> <span style="color: var(--jp-success-color0)">DEBUG</span>: Writing TrueType font.</pre>
# Writing TrueType font.
# Writing TrueType font.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
