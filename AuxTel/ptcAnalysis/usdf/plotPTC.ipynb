# %% [markdown]
# # Plot PTC

# %%
from lsst.cp.pipe.ptc.plotPtc import PlotPhotonTransferCurveTask
a =  PlotPhotonTransferCurveTask("test")

# %%
import lsst.daf.butler as dB
butler = dB.Butler("/repo/oga", collections=['u/esteves/sdf/latiss/ptc_20220922_flat'])
ptc = butler.get('ptc', instrument="LATISS", detector=0)
a.run("ptc_plots.pdf", ptc)
# Out:
# /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/cp_pipe/g6bae47012f+3129afa497/python/lsst/cp/pipe/ptc/plotPtc.py:941: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   a3.set_xlim([minMeanVecOriginal - 0.2*deltaXlim, maxMeanVecOriginal + 0.2*deltaXlim])
# /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/cp_pipe/g6bae47012f+3129afa497/python/lsst/cp/pipe/ptc/plotPtc.py:875: RuntimeWarning: invalid value encountered in sqrt
#   ptcNoise = np.sqrt((pars[2]))  # pars[2] is in (e-)^2
