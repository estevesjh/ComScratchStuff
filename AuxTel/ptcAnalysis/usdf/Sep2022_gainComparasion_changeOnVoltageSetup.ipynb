# %% [markdown]
# # Gain Comparasion: Check Change Voltage Setup
# _____
# We expect the gain values to change signficantly. The back-bias voltage setup of LATISS were change to match the main camera on late Sep. 2022.
#
# Here I will compare the gain values with our previous gain setup.
#
# _____
# Adapted to AuxTel on 11 Apr 2022\
# Initially written 18 Feb 2022 by Craig Lage.

# %%
date = '05May22'
print(f'Running this code on {date}')
# Out:
# Running this code on 05May22

# %%
import sys, os, glob, time
import numpy as np
import astropy.io.fits as pf
import matplotlib.pyplot as plt
import lsst.daf.butler as dafButler

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('notebook')
sns.set_style('whitegrid')

# %% [markdown]
# # Compare with other PTCs

# %%
def load_gain(expId, collection):
    print(f'collection, expId: {collection}, {expId}')
    butler = dafButler.Butler(repo, collections=["LATISS/raw/all","LATISS/calib",
                                                  collection])
    gain = butler.get('ptc', exposure=expId, detector=0)
    return gain

# %%
repo = "/sdf/group/rubin/repo/oga"
exposuresNew = [2022091400060, 2022092200072, 2022092700072]
collectionsNew = ['u/cslage/sdf/latiss/ptc_20220914', 'u/esteves/sdf/latiss/ptc_20220922_flat',
                  'u/cslage/sdf/latiss/ptc_20220927J']

gainsNew = []
for i in range(len(exposuresNew)):
    gainsNew.append(load_gain(exposuresNew[i], collectionsNew[i]))
# Out:
# collection, expId: u/cslage/sdf/latiss/ptc_20220914, 2022091400060
# collection, expId: u/esteves/sdf/latiss/ptc_20220922_flat, 2022092200072
# collection, expId: u/cslage/sdf/latiss/ptc_20220927J, 2022092700072

# %%
def plot_gain_channel(ptcDataset, ax=None, **kwargs):
    if ax is None: ax = plt.axes()
    gain_data = ptcDataset.gain
    gain_err_data = ptcDataset.gainErr
    amps = gain_data.keys()
    gains = []
    gain_err = []
    amp_nums = []
    for ii, amp in enumerate(amps):
        gains.append(gain_data[amp])
        gain_err.append(gain_err_data[amp])
        amp_nums.append(ii)
    ax.errorbar(amp_nums, gains, yerr=gain_err, **kwargs)
    # plt.ylim(0.95, 1.4)
    ax.set_ylabel("Gain", fontsize=16)
    ax.set_xticks(amp_nums,amps, fontsize=14)
    ax.legend(loc = 'upper right', fontsize = 14)

# plt.savefig(f'./plots/Gain_Compare_Scripts_{date}.pdf',dpi=100)

# %%
markers = len(exposures)*['o']
colors =  len(exposures)*['k']
labels = [str(exp)[:8] for exp in exposures]

# %%
markersNew = len(exposuresNew)*['*']
colorsNew =  ['tab:blue','tab:orange','tab:green']
labelsNew = [str(exp)[:8] for exp in exposuresNew]

# %%
plt.figure(figsize=(10,4))
plt.title("AuxTel Gains - September 2022", fontsize=24)

for i,gData in enumerate(gainsNew):
    plot_gain_channel(gData, ax=plt.gca(), 
                      color=colorsNew[i], ls='--', marker=markersNew[i], label=labelsNew[i])

plt.ylim(1.02,1.38)
plt.legend(loc=0, fontsize=14)
plt.savefig(f'../plots/gain_Sep2022.png',dpi=100, transparent=False, facecolor='w')

# %%
RAFT = 'RXX'
butlers = [butler1, butler2, butler3, butler4]
exposures = [exposure1, exposure2, exposure3, exposure4]
run_names = ['Feb2021-Empty', 'Mar2022-SDSSr', 'May2022-SDSSi', 'May2022-SDSSg']
markers = ['o', 'x', 'P', '*', '^', 'v']

# %%
plt.figure(figsize=(10,4))
plt.title("AuxTel Gains", fontsize=24)
for i,butler in enumerate(butlers):
    run_name = run_names[i]
    ptcDataset = butler.get('ptc', exposure=exposures[i], detector=0)
    gain_data = ptcDataset.gain
    gain_err_data = ptcDataset.gainErr
    amps = gain_data.keys()
    gains = []
    gain_err = []
    amp_nums = []
    for ii, amp in enumerate(amps):
        gains.append(gain_data[amp])
        gain_err.append(gain_err_data[amp])
        amp_nums.append(ii)
    plt.errorbar(amp_nums, gains, yerr=gain_err, marker = markers[i], label = run_name)
    plt.ylim(0.95, 1.4)
    plt.ylabel("Gain")
    plt.xticks(amp_nums,amps, fontsize=14)
    plt.legend(loc = 'upper right', fontsize = 14)

plt.savefig(f'./plots/Gain_Summary_{date}.pdf',dpi=100)
# Out:
# Previous version found for PTC dataset: 1.0. Setting 'ptcTurnoff' in all amps to last value in 'finalMeans'.
# Previous version found for PTC dataset: 1.0. Setting 'ptcTurnoff' in all amps to last value in 'finalMeans'.
# Previous version found for PTC dataset: 1.0. Setting 'ptcTurnoff' in all amps to last value in 'finalMeans'.
# Reading from location file:///sdf/group/rubin/repo/main/u/jesteves/latiss/ptc_20220504_flat/20220506T074230Z/ptc/ptc_LATISS_RXX_S00_u_jesteves_latiss_ptc_20220504_flat_20220506T074230Z.fits  with formatter lsst.obs.base.formatters.fitsGeneric.FitsGenericFormatter: Took 0.1131 seconds
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/datastores/fileDatastore.py:1341, in FileDatastore._read_artifact_into_memory(self, getInfo, ref, isComponent, cache_ref)
#    1331         with time_this(
#    1332             log,
#    1333             msg="Reading%s from location %s %s with formatter %s",
#    (...)
#    1339             ),
#    1340         ):
# -> 1341             result = formatter.read(component=getInfo.component if isComponent else None)
#    1342 except Exception as e:
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/formatters/file.py:185, in FileFormatter.read(self, component)
#     184 path = self.fileDescriptor.location.path
# --> 185 data = self._readFile(path, self.fileDescriptor.storageClass.pytype)
#     187 # Assemble the requested dataset and potentially return only its
#     188 # component coercing it to its appropriate pytype
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/obs_base/g188f660963+e1f1daa193/python/lsst/obs/base/formatters/fitsGeneric.py:61, in FitsGenericFormatter._readFile(self, path, pytype)
#      59         pass
# ---> 61 return pytype.readFits(path)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ip_isr/g564bce9563+81be7c017b/python/lsst/ip/isr/calibType.py:477, in IsrCalib.readFits(cls, filename, **kwargs)
#     476 calibClass = cls.determineCalibClass(tableList[0].meta, "readFits")
# --> 477 return calibClass.fromTable(tableList, **kwargs)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/ip_isr/g564bce9563+81be7c017b/python/lsst/ip/isr/ptcDataset.py:496, in PhotonTransferCurveDataset.fromTable(cls, tableList)
#     495 if calibVersion == 1.0:
# --> 496     mask = record['FINAL_MEANS'].mask
#     497     array = record['FINAL_MEANS'][~mask]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mask'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       3 for i,butler in enumerate(butlers):
#       4     run_name = run_names[i]
# ----> 5     ptcDataset = butler.get('ptc', exposure=exposures[i], detector=0)
#       6     gain_data = ptcDataset.gain
#       7     gain_err_data = ptcDataset.gainErr
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/_butler.py:1388, in Butler.get(self, datasetRefOrType, dataId, parameters, collections, **kwargs)
#    1386 log.debug("Butler get: %s, dataId=%s, parameters=%s", datasetRefOrType, dataId, parameters)
#    1387 ref = self._findDatasetRef(datasetRefOrType, dataId, collections=collections, **kwargs)
# -> 1388 return self.getDirect(ref, parameters=parameters)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/_butler.py:1246, in Butler.getDirect(self, ref, parameters)
#    1226 def getDirect(self, ref: DatasetRef, *, parameters: Optional[Dict[str, Any]] = None) -> Any:
#    1227     """Retrieve a stored dataset.
#    1228
#    1229     Unlike `Butler.get`, this method allows datasets outside the Butler's
#    (...)
#    1244         The dataset.
#    1245     """
# -> 1246     return self.datastore.get(ref, parameters=parameters)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/datastores/fileDatastore.py:2133, in FileDatastore.get(self, ref, parameters)
#    2126 else:
#    2127     # For an assembled composite this could be a derived
#    2128     # component derived from a real component. The validity
#    2129     # of the parameters is not clear. For now validate against
#    2130     # the composite storage class
#    2131     getInfo.formatter.fileDescriptor.storageClass.validateParameters(parameters)
# -> 2133 return self._read_artifact_into_memory(getInfo, ref, isComponent=isComponent, cache_ref=cache_ref)
#
# File /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/daf_butler/g35a551b10e+17c7ad0751/python/lsst/daf/butler/datastores/fileDatastore.py:1343, in FileDatastore._read_artifact_into_memory(self, getInfo, ref, isComponent, cache_ref)
#    1341             result = formatter.read(component=getInfo.component if isComponent else None)
#    1342 except Exception as e:
# -> 1343     raise ValueError(
#    1344         f"Failure from formatter '{formatter.name()}' for dataset {ref.id}"
#    1345         f" ({ref.datasetType.name} from {uri}): {e}"
#    1346     ) from e
#    1348 # File was read successfully so can move to cache
#    1349 if can_be_cached:
#
# ValueError: Failure from formatter 'lsst.obs.base.formatters.fitsGeneric.FitsGenericFormatter' for dataset e0ff5f69-7d51-4ef2-9d2f-17ee6d7e1054 (ptc from file:///sdf/group/rubin/repo/main/u/jesteves/latiss/ptc_20220504_flat/20220506T074230Z/ptc/ptc_LATISS_RXX_S00_u_jesteves_latiss_ptc_20220504_flat_20220506T074230Z.fits): 'numpy.ndarray' object has no attribute 'mask'

# %%
exposure2a = 2022040500096
butler2a = dafButler.Butler("/repo/main", collections=["LATISS/raw/all","LATISS/calib",
                                                      "u/jesteves/latiss/ptc_20220405"])
exposure2b = 2022040500096
butler2b = dafButler.Butler("/repo/main", collections=["LATISS/raw/all","LATISS/calib",
                                                      "u/jesteves/latiss/ptc_20220405_flat"])

exposure2c = 2022040500096
butler2c = dafButler.Butler("/repo/main", collections=["LATISS/raw/all","LATISS/calib",
                                                      "u/jesteves/latiss/ptc_20220405_rerun"])

# %%
RAFT = 'RXX'
butlers = [butler2a, butler2b, butler2c]
exposures = [exposure2a, exposure2b, exposure2c]
run_names = ['Craig`s script','Current DM script: doFlat:Fale', 'Current DM script']
markers = ['o', 'x', 'P', '*', '^', 'v']

# %%
plt.figure(figsize=(10,4))
plt.title("AuxTel Gains", fontsize=24)
for i,butler in enumerate(butlers):
    run_name = run_names[i]
    ptcDataset = butler.get('ptc', exposure=exposures[i], detector=0)
    gain_data = ptcDataset.gain
    gain_err_data = ptcDataset.gainErr
    amps = gain_data.keys()
    gains = []
    gain_err = []
    amp_nums = []
    for ii, amp in enumerate(amps):
        gains.append(gain_data[amp])
        gain_err.append(gain_err_data[amp])
        amp_nums.append(ii)
    plt.errorbar(amp_nums, gains, yerr=gain_err, marker = markers[i], label = run_name)
    # plt.ylim(0.95, 1.4)
    plt.ylabel("Gain")
    plt.xticks(amp_nums,amps, fontsize=14)
    plt.legend(loc = 'upper right', fontsize = 14)

plt.savefig(f'./plots/Gain_Compare_Scripts_{date}.pdf',dpi=100)

# %% [markdown]
# ## Investigating the Diffences on Gain
#
# Chris Stubs said that this could be due to:
# <li> temperature dependence
# <li> reduction artifacts
# <li> temporal instability
# </li>
#
# Let's start by re-running the 20220504 exposure.

# %% [markdown]
# ### Re-run the 20220504 exposure
#
# Synthax:
# ```
# pipetask run -j 32 -d "detector IN (0) AND instrument='LATISS' AND \
# 	 exposure IN (${obsDate}${flat_ptc0}..${obsDate}${flat_ptc1}) AND exposure.observation_type='flat'" \
# 	 -b /repo/main \
#      -c isr:doFlat=False \
#      -i LATISS/raw/all,LATISS/calib,LATISS/calib,u/jesteves/calib/latiss/calib.${obsDate} \
# 	 -o u/jesteves/latiss/ptc_${obsDate}_flat_rerun \
# 	 -p $CP_PIPE_DIR/pipelines/Latiss/cpPtc.yaml \
# 	 --register-dataset-types
#
# ```

# %%
exposure3 = 2022050400134
butler3 = dafButler.Butler("/repo/main", collections=["LATISS/raw/all","LATISS/calib",
                                                      "u/jesteves/latiss/ptc_20220504_flat_rerun"])

RAFT = 'RXX'
butlers = [butler1, butler2, butler3, butler4]
exposures = [exposure1, exposure2, exposure3, exposure4]
run_names = ['Feb2021-Empty', 'Mar2022-SDSSr', 'May2022-SDSSi', 'May2022-SDSSg']
markers = ['o', 'x', 'P', '*', '^', 'v']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')

# %%
data = np.zeros(len(butlers), dtype=[('gain', float), 
                                     ('gain_err', float)])
plt.figure(figsize=(10,4))
plt.title("AuxTel Gains", fontsize=24)
for i,butler in enumerate(butlers):
    run_name = run_names[i]
    ptcDataset = butler.get('ptc', exposure=exposures[i], detector=0)
    gain_data = ptcDataset.gain
    gain_err_data = ptcDataset.gainErr
    amps = gain_data.keys()
    gains = []
    gain_err = []
    amp_nums = []
    for ii, amp in enumerate(amps):
        gains.append(gain_data[amp])
        gain_err.append(gain_err_data[amp])
        amp_nums.append(ii)
    plt.errorbar(amp_nums, gains, yerr=gain_err, marker = markers[i], label = run_name)
    plt.ylim(0.95, 1.4)
    plt.ylabel("Gain")
    plt.xticks(amp_nums,amps, fontsize=14)
    plt.legend(loc = 'upper right', fontsize = 14)
    data[i] = (np.nanmean(gains), np.sqrt(np.nanstd(gains)**2+np.nanmean(gain_err)**2))

# plt.savefig(f'./plots/Gain_Summary_{date}.pdf',dpi=100)

# %% [markdown]
# Still the same result. Let's try the temperature.

# %%
data
# Out:
# array([(1.09561699, 0.0585642 ), (1.08590589, 0.0189288 ),
#        (1.04432231, 0.01654826), (1.09119877, 0.02678704)],
#       dtype=[('gain', '<f8'), ('gain_err', '<f8')])

# %% [markdown]
# ### Temperature Dependence

# %%
from lsst_efd_client import EfdClient, resample
from astropy.time import Time, TimeDelta

efd_client = EfdClient('summit_efd')

# %%
times = []
for i in range(len(exposures)):
    metadata = butler.get('raw.metadata', exposure=exposures[i], detector=0)
    times.append(Time(metadata.toDict()['DATE'], format='isot', scale='tai'))
    
times
# Out:
# [<Time object: scale='tai' format='isot' value=2021-02-17T21:03:02.965>,
#  <Time object: scale='tai' format='isot' value=2022-04-05T20:51:34.765>,
#  <Time object: scale='tai' format='isot' value=2022-05-04T20:20:43.615>,
#  <Time object: scale='tai' format='isot' value=2022-05-05T21:07:12.695>]

# %%
temp_data = np.zeros(len(times), dtype=[('t1', float), 
                                        ('t1_err', float),
                                        ('t2', float), 
                                        ('t2_err', float)])

# %%
for i in range(len(times)):

    if exposures[i] < 20211013:
        # EFD was switched to UTC on 20211013.  This compensates for that.
        tai_offset = 37.0
    else:
        tai_offset = 0.0
        
    t1 = times[i] - TimeDelta(-10., format='sec', scale='tai')
    t2 = times[i] + TimeDelta(180., format='sec', scale='tai')

    res1 = await efd_client.select_time_series("lsst.sal.ATCamera.focal_plane_Reb", 
                                               ["aspicl_Temp00","aspicu_Temp00"], 
                                               t1.utc - TimeDelta(tai_offset, format='sec'), 
                                               t2.utc - TimeDelta(tai_offset, format='sec'))
    print(res1)
    if len(res1)>0:
        t1 = np.mean(res1['aspicl_Temp00'])
        t1_err = np.std(res1['aspicl_Temp00'])
        t2 = np.mean(res1['aspicu_Temp00'])
        t2_err = np.std(res1['aspicu_Temp00'])

    else:
        t1 = np.nan
        t1_err = np.nan
        t2 = np.nan
        t2_err = np.nan
        
    temp_data[i] = (t1,t1_err,t2,t2_err)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#                                   aspicl_Temp00  aspicu_Temp00
# 2022-04-05 20:51:12.571000+00:00      16.428572      16.428572
# 2022-04-05 20:51:23.235000+00:00      16.406250      16.428572
# 2022-04-05 20:51:33.235000+00:00      16.428572      16.450893
# 2022-04-05 20:51:42.570000+00:00      16.428572      16.607143
# 2022-04-05 20:51:53.234000+00:00      16.495535      16.540178
# 2022-04-05 20:51:59.310000+00:00      16.540178      16.607143
# 2022-04-05 20:52:12.312000+00:00      16.428572      16.428572
# 2022-04-05 20:52:22.500000+00:00      16.428572      16.450893
# 2022-04-05 20:52:32.571000+00:00      16.428572      16.428572
# 2022-04-05 20:52:42.571000+00:00      16.428572      16.450893
# 2022-04-05 20:52:53.235000+00:00      16.428572      16.428572
# 2022-04-05 20:53:02.570000+00:00      16.651785      16.540178
# 2022-04-05 20:53:13.234000+00:00      16.428572      16.450893
# 2022-04-05 20:53:19.310000+00:00      16.428572      16.428572
# 2022-04-05 20:53:32.309000+00:00      16.584822      16.495535
# 2022-04-05 20:53:39.311000+00:00      16.696428      16.562500
# 2022-04-05 20:53:42.309000+00:00      16.696428      16.562500
# 2022-04-05 20:53:52.309000+00:00      16.428572      16.450893
# 2022-04-05 20:53:52.501000+00:00      16.428572      16.450893
#                                   aspicl_Temp00  aspicu_Temp00
# 2022-05-04 20:20:23.439000+00:00      15.915178      16.049107
# 2022-05-04 20:20:31.474000+00:00      15.892858      15.915178
# 2022-05-04 20:20:42.036000+00:00      15.915178      15.937500
# 2022-05-04 20:20:53.441000+00:00      16.116072      16.093750
# 2022-05-04 20:21:03.442000+00:00      15.937500      15.959822
# 2022-05-04 20:21:09.169000+00:00      16.093750      15.870536
# 2022-05-04 20:21:21.474000+00:00      15.892858      15.892858
# 2022-05-04 20:21:31.475000+00:00      15.892858      15.892858
# 2022-05-04 20:21:42.036000+00:00      15.937500      16.026785
# 2022-05-04 20:21:52.037000+00:00      16.049107      16.004465
# 2022-05-04 20:22:03.438000+00:00      15.848214      15.892858
# 2022-05-04 20:22:11.474000+00:00      16.116072      15.848214
# 2022-05-04 20:22:22.036000+00:00      16.049107      15.959822
# 2022-05-04 20:22:32.037000+00:00      15.870536      15.870536
# 2022-05-04 20:22:43.437000+00:00      15.870536      15.870536
# 2022-05-04 20:22:48.219000+00:00      15.982142      15.848214
# 2022-05-04 20:22:59.168000+00:00      15.848214      15.870536
#                                   aspicl_Temp00  aspicu_Temp00
# 2022-05-05 21:06:52.037000+00:00      16.495535      16.495535
# 2022-05-05 21:07:03.438000+00:00      16.629465      16.607143
# 2022-05-05 21:07:11.474000+00:00      16.584822      16.696428
# 2022-05-05 21:07:22.036000+00:00      16.651785      16.450893
# 2022-05-05 21:07:32.042000+00:00      16.495535      16.495535
# 2022-05-05 21:07:43.439000+00:00      16.517857      16.495535
# 2022-05-05 21:07:51.474000+00:00      16.629465      16.495535
# 2022-05-05 21:08:01.475000+00:00      16.495535      16.517857
# 2022-05-05 21:08:11.475000+00:00      16.584822      16.696428
# 2022-05-05 21:08:22.036000+00:00      16.495535      16.517857
# 2022-05-05 21:08:33.441000+00:00      16.718750      16.607143
# 2022-05-05 21:08:43.437000+00:00      16.517857      16.540178
# 2022-05-05 21:08:49.168000+00:00      16.517857      16.517857
# 2022-05-05 21:09:01.474000+00:00      16.651785      16.674107
# 2022-05-05 21:09:12.036000+00:00      16.517857      16.540178
# 2022-05-05 21:09:23.440000+00:00      16.517857      16.517857
# 2022-05-05 21:09:28.220000+00:00      16.517857      16.517857

# %%
temp_data
# Out:
# array([(        nan,        nan,         nan,        nan),
#        (16.48496246, 0.09590358, 16.48378784, 0.06245308),
#        (15.95456931, 0.09140386, 15.92962192, 0.07260913),
#        (16.56118662, 0.06868042, 16.55199545, 0.07348262)],
#       dtype=[('t1', '<f8'), ('t1_err', '<f8'), ('t2', '<f8'), ('t2_err', '<f8')])

# %%
data
# Out:
# array([(1.09561699, 0.0585642 ), (1.08590589, 0.0189288 ),
#        (1.04432231, 0.01654826), (1.09119877, 0.02678704)],
#       dtype=[('gain', '<f8'), ('gain_err', '<f8')])

# %%
fig, ax = plt.subplots(1, 2, sharex='col', sharey='row',figsize=(10,5))
for i in range(len(exposures)):
    ax[0].scatter(temp_data['t2'][i],data['gain'][i],s=100,label=run_names[i])
ax[0].legend(fontsize=12)
ax[0].errorbar(temp_data['t2'],data['gain'],xerr=temp_data['t2_err'],yerr=data['gain_err'],
             fmt='.w',capsize=3,ecolor='k')

ax[0].set_xlabel('Temp [°C]: aspicu_Temp00')
ax[0].set_ylabel('Mean Gain')
ax[0].set_title('Auxtel: May 13 2022')

for i in range(len(exposures)):
    ax[1].scatter(temp_data['t1'][i],data['gain'][i],s=100,label=run_names[i])
ax[1].legend(fontsize=12)
ax[1].errorbar(temp_data['t1'],data['gain'],xerr=temp_data['t1_err'],yerr=data['gain_err'],
             fmt='.w',capsize=3,ecolor='k')

ax[1].set_xlabel('Temp [°C]: aspicl_Temp00')
fig.subplots_adjust(hspace=0.4, wspace=0.4)
fig.tight_layout()
fig.savefig(f'./plots/temp_gain_relation_May13.pdf',dpi=100)

# %%
for i in range(len(exposures)):
    plt.scatter(temp_data['t2'][i],data['gain'][i],s=100,label=run_names[i])
plt.legend(fontsize=12)
plt.errorbar(temp_data['t2'],data['gain'],xerr=temp_data['t2_err'],yerr=data['gain_err'],
             fmt='.w',capsize=3,ecolor='k')

plt.xlabel('Temp [°C]: aspicu_Temp00')
plt.ylabel('Mean Gain')
plt.title('Auxtel: May 13 2022')
# plt.xlim(15.8,16.5)
# Out:
# Text(0.5, 1.0, 'Auxtel: May 13 2022')

# %%
dashboardTime = metadata.toDict()['DATE']
upperDashboardTime = metadata.toDict()['DATE'][:-6]+str(float(metadata.toDict()['DATE'][-6:])+5.)
query = f"""SELECT "aspicl_Temp00", "aspicu_Temp00" FROM "efd"."autogen"."lsst.sal.ATCamera.focal_plane_Reb" WHERE time > :{dashboardTime}: AND time < :{upperDashboardTime}:"""
print(query)
# Out:
# SELECT "aspicl_Temp00", "aspicu_Temp00" FROM "efd"."autogen"."lsst.sal.ATCamera.focal_plane_Reb" WHERE time > :2022-05-05T21:07:12.695: AND time < :2022-05-05T21:07:17.695:

# %%
# res = await efd_client.influx_client.query(query)
